# %%
import fitsio, starburstspec, ebossspec
import datapath
from os.path import join, isfile
import cosmology as cosmo
objs_ori = ebossspec.elg_readin()
nobj = objs_ori.size
galaxytype = objs_ori['CLASS']
zgood = objs_ori['zGOOD']
z = objs_ori['Z']
inuv = (where(logical_and(logical_and(logical_and(zgood, 
                                                   z>0.6), z<1.2), galaxytype=='GALAXY')))[0]

# %%
(master_wave, rest_allflux, rest_allivar) = starburstspec.rest_allspec_readin()
# Out:
# Reading /Users/Benjamin/AstroData/AllInOne/AIO_SBSF_HSTFOS_NEDzRestFrame_Wave00900_01800A.fits.
# Reading /Users/Benjamin/AstroData/AllInOne/AIO_SBSF_HSTFOS_NEDzRestFrame_Wave01800_03600A.fits.

# %%
(outwave, fluxmean, fluxmedian, fluxused) = starburstspec.mgii_composite()
# Out:
# Reading /Users/Benjamin/AstroData/AllInOne/AIO_SBSF_HSTFOS_NEDzRestFrame_Wave00900_01800A.fits.
# Reading /Users/Benjamin/AstroData/AllInOne/AIO_SBSF_HSTFOS_NEDzRestFrame_Wave01800_03600A.fits.

# %%
fig = figure(figsize=(20,7))
ax = fig.add_subplot(111)
ax.set_xlim(2200,3200)
ax.set_ylim(0,1.2)
ax.plot(outwave, fluxmedian)
ax.plot(master_wave, rest_allflux[:,44])

# %%
import cookb_signalsmooth as cbs

# %%
fig = figure(figsize=(20,7))
ax = fig.add_subplot(111)
ax.set_xlim(2400,2800)
ax.set_ylim(0.4,1.4)
plot(master_wave, rest_allflux[:,45]*1E15)

# %%
pscale = array([0.002, 0.012, 0.037, 0.036, 0.015, 0.030])
pdist = cosmo.angdiameter_distance(z[inuv])*1E3*2./3600./180.*pi

# %%
fig = figure(figsize=(9,7))
ax = fig.add_subplot(111)
n, bins, patches = ax.hist(pscale, bins=logspace(log10(0.001), log10(50), 50), edgecolor='black', normed=True)
n, bins, patches = ax.hist(pdist, bins=logspace(log10(0.001), log10(50), 50), edgecolor='black', normed=True)
ax.set_xlim(0.001, 30.)
ax.set_xscale('log')

# %%
fig = figure(figsize=(9,7))
ax = fig.add_subplot(111)
data = np.random.normal(size=10000)
ax.hist(data, bins=np.logspace(0.1, 1.0, 50))
ax.set_xscale("log")

# %%
fig = figure(figsize=(9,7))
ax = fig.add_subplot(111)
#n, bins, patches = ax.hist(pdist, bins=logspace(log10(10), log10(100), 50), edgecolor='black', normed=True)
n, bins, patches = ax.hist(pdist, bins=linspace(13, 17, 50), edgecolor='black', normed=True)
ax.set_xlim(13, 17.)
#ax.set_xscale('log')
# Out:
# (13, 17.0)

# %%
pscale
# Out:
# array([ 0.002,  0.012,  0.037,  0.036,  0.015,  0.03 ])

# %%
import numpy as np
import matplotlib.pyplot as plt
import starburstspec

# %%
starburstspec.save_mgii_composite()
# Out:
# Reading /Users/Benjamin/AstroData/AllInOne/AIO_SBSF_HSTFOS_NEDzRestFrame_Wave00900_01800A.fits.
# Reading /Users/Benjamin/AstroData/AllInOne/AIO_SBSF_HSTFOS_NEDzRestFrame_Wave01800_03600A.fits.
# Write into file: /Users/Benjamin/AstroData/HST/FOS/starburst/fos_ghrs_spectra/starburst_mgii_composite.fits.

# %%
a = starburstspec.mgii_composite_readin()

# %%
a.dtype
# Out:
# dtype([('WAVE', '>f4', (1200,)), ('FLUXMEDIAN', '>f4', (1200,)), ('FLUXMEAN', '>f4', (1200,)), ('FLUXUSED', '>f4', (1200, 9))])

# %%
plt.plot(a['WAVE'], a['FLUXMEDIAN'])
